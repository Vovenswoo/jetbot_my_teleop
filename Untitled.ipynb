# %%
print("Стоп")
left_motor.stop()
right_motor.stop()
# Out:
# Стоп
# ---------------------------------------------------------------
# NameError                     Traceback (most recent call last)
# <ipython-input-1-7d55c2fe1482> in <module>
#       1 print("Стоп")
# ----> 2 left_motor.stop()
#       3 right_motor.stop()
#
# NameError: name 'left_motor' is not defined

# %%
import smbus
import time
import atexit
import threading

# %%
print("Стоп")
left_motor.stop()
right_motor.stop()
# Out:
# Стоп
# ---------------------------------------------------------------
# NameError                     Traceback (most recent call last)
# <ipython-input-4-7d55c2fe1482> in <module>
#       1 print("Стоп")
# ----> 2 left_motor.stop()
#       3 right_motor.stop()
#
# NameError: name 'left_motor' is not defined
